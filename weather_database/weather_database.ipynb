# %%
#Import Dependencies
import requests
import pandas as pd
from config import weather_api_key
import random
import numpy as np
from citipy import citipy
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Add coordinates to list
coords = list(lat_lngs)

# %%
#Get nearest city for lat, long combos
cities = [] #empty list for cities
countries = [] #empty list for country
for coord in coords:
    city = citipy.nearest_city(coord[0], coord[1]).city_name
    if city not in cities:
        cities.append(city)

# %%
#Length of cities list
print(len(cities))
# Out:
# 722

# %%
#Call OpenWeather API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+weather_api_key

# %%
#Empty list for city data
city_data=[]

#tracker set up
record_count= 1
set_count = 1

#Loop through all the cities in our list. 
for i, city in enumerate(cities): 
    
    #Group citiies in sets of 50 for logging purposes. 
    if (i% 50 == 0 and i >=50):
        set_count += 1
        record_count =1
        time.sleep(60)
        
    #Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    #Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_descript = city_weather["weather"][0]["main"]
        city_details = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date, 
                          "Description":city_details
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | arraial do cabo
# Processing Record 2 of Set 1 | portland
# Processing Record 3 of Set 1 | barrow
# Processing Record 4 of Set 1 | churapcha
# Processing Record 5 of Set 1 | cape town
# Processing Record 6 of Set 1 | shadegan
# Processing Record 7 of Set 1 | aranos
# Processing Record 8 of Set 1 | butaritari
# Processing Record 9 of Set 1 | kavali
# Processing Record 10 of Set 1 | lebu
# Processing Record 11 of Set 1 | norman wells
# Processing Record 12 of Set 1 | pacasmayo
# Processing Record 13 of Set 1 | cauquenes
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | khatanga
# Processing Record 17 of Set 1 | tazovskiy
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | airai
# Processing Record 21 of Set 1 | muroto
# Processing Record 22 of Set 1 | hilo
# Processing Record 23 of Set 1 | bandarbeyla
# Processing Record 24 of Set 1 | atuona
# Processing Record 25 of Set 1 | bengkulu
# Processing Record 26 of Set 1 | husavik
# Processing Record 27 of Set 1 | ribeira grande
# Processing Record 28 of Set 1 | vaini
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | kantabanji
# Processing Record 31 of Set 1 | doka
# Processing Record 32 of Set 1 | hobart
# Processing Record 33 of Set 1 | iqaluit
# Processing Record 34 of Set 1 | cherskiy
# Processing Record 35 of Set 1 | oksfjord
# Processing Record 36 of Set 1 | keetmanshoop
# Processing Record 37 of Set 1 | kayfan
# City not found. Skipping...
# Processing Record 38 of Set 1 | moron
# Processing Record 39 of Set 1 | hithadhoo
# Processing Record 40 of Set 1 | komsomolskiy
# Processing Record 41 of Set 1 | vardo
# Processing Record 42 of Set 1 | chicama
# Processing Record 43 of Set 1 | guerrero negro
# Processing Record 44 of Set 1 | nikolskoye
# Processing Record 45 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 1 | shitanjing
# Processing Record 47 of Set 1 | severo-kurilsk
# Processing Record 48 of Set 1 | anahuac
# Processing Record 49 of Set 1 | upernavik
# Processing Record 50 of Set 1 | busselton
# Processing Record 1 of Set 2 | kavieng
# Processing Record 2 of Set 2 | castro
# Processing Record 3 of Set 2 | new norfolk
# Processing Record 4 of Set 2 | sydney
# Processing Record 5 of Set 2 | birjand
# Processing Record 6 of Set 2 | mehamn
# Processing Record 7 of Set 2 | ballina
# Processing Record 8 of Set 2 | waverly
# Processing Record 9 of Set 2 | terney
# Processing Record 10 of Set 2 | vanersborg
# Processing Record 11 of Set 2 | cidreira
# Processing Record 12 of Set 2 | ugoofaaru
# Processing Record 13 of Set 2 | trat
# Processing Record 14 of Set 2 | araouane
# Processing Record 15 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 16 of Set 2 | yellowknife
# Processing Record 17 of Set 2 | sao joao do piaui
# Processing Record 18 of Set 2 | pangkalanbuun
# Processing Record 19 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 20 of Set 2 | hasaki
# Processing Record 21 of Set 2 | georgetown
# Processing Record 22 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 2 | kodiak
# Processing Record 24 of Set 2 | puerto ayora
# Processing Record 25 of Set 2 | subaytilah
# City not found. Skipping...
# Processing Record 26 of Set 2 | srednekolymsk
# Processing Record 27 of Set 2 | kisangani
# Processing Record 28 of Set 2 | luwuk
# Processing Record 29 of Set 2 | souillac
# Processing Record 30 of Set 2 | mataura
# Processing Record 31 of Set 2 | aklavik
# Processing Record 32 of Set 2 | tuatapere
# Processing Record 33 of Set 2 | pisco
# Processing Record 34 of Set 2 | saint-philippe
# Processing Record 35 of Set 2 | muromtsevo
# Processing Record 36 of Set 2 | sakaiminato
# Processing Record 37 of Set 2 | qaanaaq
# Processing Record 38 of Set 2 | constitucion
# Processing Record 39 of Set 2 | skjervoy
# Processing Record 40 of Set 2 | aniva
# Processing Record 41 of Set 2 | codrington
# Processing Record 42 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 2 | lardos
# Processing Record 44 of Set 2 | nieuw amsterdam
# Processing Record 45 of Set 2 | victoria
# Processing Record 46 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 2 | carnarvon
# Processing Record 48 of Set 2 | upata
# Processing Record 49 of Set 2 | oistins
# Processing Record 50 of Set 2 | ponta do sol
# Processing Record 1 of Set 3 | chuy
# Processing Record 2 of Set 3 | dikson
# Processing Record 3 of Set 3 | velen
# Processing Record 4 of Set 3 | jamestown
# Processing Record 5 of Set 3 | laurel
# Processing Record 6 of Set 3 | linxia
# Processing Record 7 of Set 3 | brewster
# Processing Record 8 of Set 3 | kall
# Processing Record 9 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 3 | banda aceh
# Processing Record 12 of Set 3 | nanortalik
# Processing Record 13 of Set 3 | nyurba
# Processing Record 14 of Set 3 | salalah
# Processing Record 15 of Set 3 | jumla
# Processing Record 16 of Set 3 | hamilton
# Processing Record 17 of Set 3 | thompson
# Processing Record 18 of Set 3 | hermanus
# Processing Record 19 of Set 3 | port lincoln
# Processing Record 20 of Set 3 | berlevag
# Processing Record 21 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 3 | tasiilaq
# Processing Record 24 of Set 3 | khonsa
# Processing Record 25 of Set 3 | nouadhibou
# Processing Record 26 of Set 3 | rawson
# Processing Record 27 of Set 3 | broken hill
# Processing Record 28 of Set 3 | bethel
# Processing Record 29 of Set 3 | takab
# Processing Record 30 of Set 3 | staraya toropa
# Processing Record 31 of Set 3 | torbay
# Processing Record 32 of Set 3 | alenquer
# Processing Record 33 of Set 3 | anloga
# Processing Record 34 of Set 3 | tahoua
# Processing Record 35 of Set 3 | kahului
# Processing Record 36 of Set 3 | santa vitoria do palmar
# Processing Record 37 of Set 3 | larsnes
# Processing Record 38 of Set 3 | marawi
# Processing Record 39 of Set 3 | tiksi
# Processing Record 40 of Set 3 | wlodawa
# Processing Record 41 of Set 3 | vila franca do campo
# Processing Record 42 of Set 3 | muros
# Processing Record 43 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 3 | whitehorse
# Processing Record 45 of Set 3 | tuktoyaktuk
# Processing Record 46 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 3 | talnakh
# Processing Record 48 of Set 3 | tura
# Processing Record 49 of Set 3 | oron
# Processing Record 50 of Set 3 | tuggurt
# City not found. Skipping...
# Processing Record 1 of Set 4 | beringovskiy
# Processing Record 2 of Set 4 | port alfred
# Processing Record 3 of Set 4 | kourou
# Processing Record 4 of Set 4 | pemangkat
# Processing Record 5 of Set 4 | millbrook
# Processing Record 6 of Set 4 | zhangjiakou
# Processing Record 7 of Set 4 | avarua
# Processing Record 8 of Set 4 | hailey
# Processing Record 9 of Set 4 | kapaa
# Processing Record 10 of Set 4 | omboue
# Processing Record 11 of Set 4 | palmer
# Processing Record 12 of Set 4 | bonavista
# Processing Record 13 of Set 4 | east london
# Processing Record 14 of Set 4 | pimentel
# Processing Record 15 of Set 4 | parrita
# Processing Record 16 of Set 4 | roald
# Processing Record 17 of Set 4 | kumluca
# Processing Record 18 of Set 4 | tocopilla
# Processing Record 19 of Set 4 | pietarsaari
# Processing Record 20 of Set 4 | poum
# Processing Record 21 of Set 4 | sao filipe
# Processing Record 22 of Set 4 | sawtell
# Processing Record 23 of Set 4 | dubti
# Processing Record 24 of Set 4 | chokurdakh
# Processing Record 25 of Set 4 | ancud
# Processing Record 26 of Set 4 | pangnirtung
# Processing Record 27 of Set 4 | pacific grove
# Processing Record 28 of Set 4 | soe
# Processing Record 29 of Set 4 | beloha
# Processing Record 30 of Set 4 | songea
# Processing Record 31 of Set 4 | faanui
# Processing Record 32 of Set 4 | geraldton
# Processing Record 33 of Set 4 | verkhoyansk
# Processing Record 34 of Set 4 | senneterre
# Processing Record 35 of Set 4 | bemidji
# Processing Record 36 of Set 4 | bathsheba
# Processing Record 37 of Set 4 | seddon
# Processing Record 38 of Set 4 | nishihara
# Processing Record 39 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 4 | vadso
# Processing Record 41 of Set 4 | folkestone
# Processing Record 42 of Set 4 | bredasdorp
# Processing Record 43 of Set 4 | pevek
# Processing Record 44 of Set 4 | fortuna
# Processing Record 45 of Set 4 | kauhajoki
# Processing Record 46 of Set 4 | yulara
# Processing Record 47 of Set 4 | dunedin
# Processing Record 48 of Set 4 | vestmannaeyjar
# Processing Record 49 of Set 4 | ranong
# Processing Record 50 of Set 4 | yumen
# Processing Record 1 of Set 5 | cabo san lucas
# Processing Record 2 of Set 5 | matveyevka
# Processing Record 3 of Set 5 | chimbote
# Processing Record 4 of Set 5 | aykhal
# Processing Record 5 of Set 5 | mar del plata
# Processing Record 6 of Set 5 | ahuimanu
# Processing Record 7 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 5 | northam
# Processing Record 9 of Set 5 | provideniya
# Processing Record 10 of Set 5 | zvishavane
# Processing Record 11 of Set 5 | boysun
# Processing Record 12 of Set 5 | deputatskiy
# Processing Record 13 of Set 5 | ketchikan
# Processing Record 14 of Set 5 | waipawa
# Processing Record 15 of Set 5 | port elizabeth
# Processing Record 16 of Set 5 | sofiysk
# City not found. Skipping...
# Processing Record 17 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 18 of Set 5 | miri
# Processing Record 19 of Set 5 | barahan
# Processing Record 20 of Set 5 | coihaique
# Processing Record 21 of Set 5 | mastic beach
# Processing Record 22 of Set 5 | matagami
# Processing Record 23 of Set 5 | praia
# Processing Record 24 of Set 5 | malanje
# Processing Record 25 of Set 5 | hastings
# Processing Record 26 of Set 5 | mildura
# Processing Record 27 of Set 5 | klaksvik
# Processing Record 28 of Set 5 | lubango
# Processing Record 29 of Set 5 | gilgil
# City not found. Skipping...
# Processing Record 30 of Set 5 | alanya
# Processing Record 31 of Set 5 | hudson bay
# Processing Record 32 of Set 5 | sitka
# Processing Record 33 of Set 5 | snezhnogorsk
# Processing Record 34 of Set 5 | emerald
# Processing Record 35 of Set 5 | xinqing
# Processing Record 36 of Set 5 | saint-augustin
# Processing Record 37 of Set 5 | issia
# Processing Record 38 of Set 5 | san cristobal
# Processing Record 39 of Set 5 | port hardy
# Processing Record 40 of Set 5 | narsaq
# Processing Record 41 of Set 5 | erzin
# Processing Record 42 of Set 5 | san patricio
# Processing Record 43 of Set 5 | broome
# Processing Record 44 of Set 5 | karratha
# Processing Record 45 of Set 5 | esna
# Processing Record 46 of Set 5 | rio grande
# Processing Record 47 of Set 5 | noyabrsk
# Processing Record 48 of Set 5 | bata
# Processing Record 49 of Set 5 | normandin
# Processing Record 50 of Set 5 | longyearbyen
# Processing Record 1 of Set 6 | vila velha
# Processing Record 2 of Set 6 | richards bay
# Processing Record 3 of Set 6 | narrabri
# Processing Record 4 of Set 6 | hovd
# Processing Record 5 of Set 6 | taltal
# Processing Record 6 of Set 6 | bambous virieux
# Processing Record 7 of Set 6 | hof
# Processing Record 8 of Set 6 | mount gambier
# Processing Record 9 of Set 6 | kaduna
# Processing Record 10 of Set 6 | acarau
# Processing Record 11 of Set 6 | kaitangata
# Processing Record 12 of Set 6 | la ronge
# Processing Record 13 of Set 6 | gat
# Processing Record 14 of Set 6 | vanimo
# Processing Record 15 of Set 6 | tambura
# Processing Record 16 of Set 6 | sur
# Processing Record 17 of Set 6 | biltine
# Processing Record 18 of Set 6 | gamba
# Processing Record 19 of Set 6 | lagoa
# Processing Record 20 of Set 6 | kudahuvadhoo
# Processing Record 21 of Set 6 | pyay
# Processing Record 22 of Set 6 | touros
# Processing Record 23 of Set 6 | todos santos
# Processing Record 24 of Set 6 | abu samrah
# Processing Record 25 of Set 6 | clyde river
# Processing Record 26 of Set 6 | porto santo
# Processing Record 27 of Set 6 | kirakira
# Processing Record 28 of Set 6 | saskylakh
# Processing Record 29 of Set 6 | aripuana
# Processing Record 30 of Set 6 | luderitz
# Processing Record 31 of Set 6 | kaka
# Processing Record 32 of Set 6 | fare
# Processing Record 33 of Set 6 | caravelas
# Processing Record 34 of Set 6 | chapais
# Processing Record 35 of Set 6 | korla
# Processing Record 36 of Set 6 | isla mujeres
# Processing Record 37 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 6 | basco
# Processing Record 40 of Set 6 | okha
# Processing Record 41 of Set 6 | puerto baquerizo moreno
# Processing Record 42 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 43 of Set 6 | prainha
# Processing Record 44 of Set 6 | leningradskiy
# Processing Record 45 of Set 6 | akcakoca
# Processing Record 46 of Set 6 | limulunga
# Processing Record 47 of Set 6 | taoudenni
# Processing Record 48 of Set 6 | coquimbo
# Processing Record 49 of Set 6 | xingcheng
# Processing Record 50 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 7 | meulaboh
# Processing Record 2 of Set 7 | barpali
# Processing Record 3 of Set 7 | twin falls
# Processing Record 4 of Set 7 | grand gaube
# Processing Record 5 of Set 7 | perelyub
# Processing Record 6 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 7 of Set 7 | manggar
# Processing Record 8 of Set 7 | dong hoi
# Processing Record 9 of Set 7 | swan hill
# Processing Record 10 of Set 7 | yerbogachen
# Processing Record 11 of Set 7 | los llanos de aridane
# Processing Record 12 of Set 7 | tanout
# Processing Record 13 of Set 7 | ilulissat
# Processing Record 14 of Set 7 | ciudad bolivar
# Processing Record 15 of Set 7 | comodoro rivadavia
# Processing Record 16 of Set 7 | urusha
# Processing Record 17 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 7 | hervey bay
# Processing Record 19 of Set 7 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 20 of Set 7 | moranbah
# Processing Record 21 of Set 7 | sioux lookout
# Processing Record 22 of Set 7 | fez
# Processing Record 23 of Set 7 | anadyr
# Processing Record 24 of Set 7 | barkly west
# Processing Record 25 of Set 7 | college
# Processing Record 26 of Set 7 | yar-sale
# Processing Record 27 of Set 7 | bilibino
# Processing Record 28 of Set 7 | butembo
# Processing Record 29 of Set 7 | turbat
# Processing Record 30 of Set 7 | mokhsogollokh
# Processing Record 31 of Set 7 | manaus
# Processing Record 32 of Set 7 | oranjemund
# Processing Record 33 of Set 7 | diu
# Processing Record 34 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 35 of Set 7 | valparaiso
# Processing Record 36 of Set 7 | hofn
# Processing Record 37 of Set 7 | zhangye
# Processing Record 38 of Set 7 | acapulco
# Processing Record 39 of Set 7 | galle
# Processing Record 40 of Set 7 | trincomalee
# Processing Record 41 of Set 7 | falealupo
# City not found. Skipping...
# Processing Record 42 of Set 7 | tabulbah
# City not found. Skipping...
# Processing Record 43 of Set 7 | lakes entrance
# Processing Record 44 of Set 7 | mozelos
# Processing Record 45 of Set 7 | schwedt
# Processing Record 46 of Set 7 | carutapera
# Processing Record 47 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 7 | mogadishu
# Processing Record 49 of Set 7 | verkhnyaya inta
# Processing Record 50 of Set 7 | haines junction
# Processing Record 1 of Set 8 | tokur
# Processing Record 2 of Set 8 | kamina
# Processing Record 3 of Set 8 | tolaga bay
# Processing Record 4 of Set 8 | quatre cocos
# Processing Record 5 of Set 8 | bundaberg
# Processing Record 6 of Set 8 | zhumadian
# Processing Record 7 of Set 8 | alice springs
# Processing Record 8 of Set 8 | naze
# Processing Record 9 of Set 8 | herat
# Processing Record 10 of Set 8 | sinjar
# Processing Record 11 of Set 8 | felanitx
# Processing Record 12 of Set 8 | nhulunbuy
# Processing Record 13 of Set 8 | mbaiki
# Processing Record 14 of Set 8 | kasongo-lunda
# Processing Record 15 of Set 8 | rocha
# Processing Record 16 of Set 8 | dingle
# Processing Record 17 of Set 8 | kamaishi
# Processing Record 18 of Set 8 | talcahuano
# Processing Record 19 of Set 8 | brownwood
# Processing Record 20 of Set 8 | qasigiannguit
# Processing Record 21 of Set 8 | micheweni
# Processing Record 22 of Set 8 | laiagam
# City not found. Skipping...
# Processing Record 23 of Set 8 | laguna
# Processing Record 24 of Set 8 | freeport
# Processing Record 25 of Set 8 | pampa
# Processing Record 26 of Set 8 | kuytun
# Processing Record 27 of Set 8 | yeppoon
# Processing Record 28 of Set 8 | afmadu
# City not found. Skipping...
# Processing Record 29 of Set 8 | krasnoselkup
# Processing Record 30 of Set 8 | lompoc
# Processing Record 31 of Set 8 | mahebourg
# Processing Record 32 of Set 8 | nikolsk
# Processing Record 33 of Set 8 | shashi
# Processing Record 34 of Set 8 | raudeberg
# Processing Record 35 of Set 8 | puri
# Processing Record 36 of Set 8 | borger
# Processing Record 37 of Set 8 | fukue
# Processing Record 38 of Set 8 | concordia
# Processing Record 39 of Set 8 | belebey
# Processing Record 40 of Set 8 | luau
# Processing Record 41 of Set 8 | harlingen
# Processing Record 42 of Set 8 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 43 of Set 8 | tulum
# Processing Record 44 of Set 8 | grindavik
# Processing Record 45 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 46 of Set 8 | nizhniy tsasuchey
# Processing Record 47 of Set 8 | kavaratti
# Processing Record 48 of Set 8 | agbor
# Processing Record 49 of Set 8 | abha
# Processing Record 50 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 9 | brae
# Processing Record 2 of Set 9 | san policarpo
# Processing Record 3 of Set 9 | casino
# Processing Record 4 of Set 9 | pak phanang
# Processing Record 5 of Set 9 | dordrecht
# Processing Record 6 of Set 9 | neryungri
# Processing Record 7 of Set 9 | maloy
# Processing Record 8 of Set 9 | tashtagol
# Processing Record 9 of Set 9 | itanhem
# Processing Record 10 of Set 9 | yabrud
# Processing Record 11 of Set 9 | bilma
# Processing Record 12 of Set 9 | matay
# Processing Record 13 of Set 9 | saint george
# Processing Record 14 of Set 9 | port augusta
# Processing Record 15 of Set 9 | fort nelson
# Processing Record 16 of Set 9 | sept-iles
# Processing Record 17 of Set 9 | suntar
# Processing Record 18 of Set 9 | lavrentiya
# Processing Record 19 of Set 9 | kununurra
# Processing Record 20 of Set 9 | faya
# Processing Record 21 of Set 9 | leiyang
# Processing Record 22 of Set 9 | islamkot
# Processing Record 23 of Set 9 | hambantota
# Processing Record 24 of Set 9 | palmerston
# Processing Record 25 of Set 9 | palu
# Processing Record 26 of Set 9 | gushikawa
# Processing Record 27 of Set 9 | januaria
# Processing Record 28 of Set 9 | maarianhamina
# Processing Record 29 of Set 9 | ust-omchug
# Processing Record 30 of Set 9 | nagireddipalle
# City not found. Skipping...
# Processing Record 31 of Set 9 | orchard homes
# Processing Record 32 of Set 9 | barranco
# Processing Record 33 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 34 of Set 9 | vila
# Processing Record 35 of Set 9 | asyut
# Processing Record 36 of Set 9 | alekseyevsk
# Processing Record 37 of Set 9 | zheleznodorozhnyy
# Processing Record 38 of Set 9 | witu
# Processing Record 39 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 40 of Set 9 | oriximina
# Processing Record 41 of Set 9 | providencia
# Processing Record 42 of Set 9 | merzifon
# Processing Record 43 of Set 9 | erenhot
# Processing Record 44 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 45 of Set 9 | zimapan
# Processing Record 46 of Set 9 | lata
# Processing Record 47 of Set 9 | chute-aux-outardes
# Processing Record 48 of Set 9 | prieska
# Processing Record 49 of Set 9 | olafsvik
# Processing Record 50 of Set 9 | udachnyy
# Processing Record 1 of Set 10 | maradi
# Processing Record 2 of Set 10 | westport
# Processing Record 3 of Set 10 | tres picos
# Processing Record 4 of Set 10 | moose factory
# Processing Record 5 of Set 10 | paris
# Processing Record 6 of Set 10 | samarai
# Processing Record 7 of Set 10 | tiznit
# Processing Record 8 of Set 10 | neka
# Processing Record 9 of Set 10 | amahai
# Processing Record 10 of Set 10 | quang ngai
# Processing Record 11 of Set 10 | tilichiki
# Processing Record 12 of Set 10 | hays
# Processing Record 13 of Set 10 | biak
# Processing Record 14 of Set 10 | lerwick
# Processing Record 15 of Set 10 | tra vinh
# Processing Record 16 of Set 10 | bubaque
# Processing Record 17 of Set 10 | antalaha
# Processing Record 18 of Set 10 | tigil
# Processing Record 19 of Set 10 | calama
# Processing Record 20 of Set 10 | kondinskoye
# Processing Record 21 of Set 10 | santo antonio do ica
# Processing Record 22 of Set 10 | siloam springs
# Processing Record 23 of Set 10 | penzance
# Processing Record 24 of Set 10 | oussouye
# Processing Record 25 of Set 10 | mocuba
# Processing Record 26 of Set 10 | kilindoni
# Processing Record 27 of Set 10 | majagual
# Processing Record 28 of Set 10 | fujin
# Processing Record 29 of Set 10 | namatanai
# Processing Record 30 of Set 10 | vostok
# Processing Record 31 of Set 10 | dongzhen
# Processing Record 32 of Set 10 | mae hong son
# Processing Record 33 of Set 10 | moita bonita
# Processing Record 34 of Set 10 | ulagan
# Processing Record 35 of Set 10 | alice town
# Processing Record 36 of Set 10 | opuwo
# Processing Record 37 of Set 10 | panaba
# Processing Record 38 of Set 10 | conceicao do araguaia
# Processing Record 39 of Set 10 | barcelos
# Processing Record 40 of Set 10 | atikokan
# Processing Record 41 of Set 10 | rognan
# Processing Record 42 of Set 10 | coro
# Processing Record 43 of Set 10 | bad reichenhall
# Processing Record 44 of Set 10 | ostrovnoy
# Processing Record 45 of Set 10 | aktau
# Processing Record 46 of Set 10 | sokoni
# Processing Record 47 of Set 10 | khilok
# Processing Record 48 of Set 10 | sobolevo
# Processing Record 49 of Set 10 | karauzyak
# City not found. Skipping...
# Processing Record 50 of Set 10 | thessaloniki
# Processing Record 1 of Set 11 | kruisfontein
# Processing Record 2 of Set 11 | saint-joseph
# Processing Record 3 of Set 11 | qaqortoq
# Processing Record 4 of Set 11 | zachary
# Processing Record 5 of Set 11 | saldanha
# Processing Record 6 of Set 11 | crotone
# Processing Record 7 of Set 11 | cumaribo
# City not found. Skipping...
# Processing Record 8 of Set 11 | havre-saint-pierre
# Processing Record 9 of Set 11 | mao
# Processing Record 10 of Set 11 | guilin
# Processing Record 11 of Set 11 | isangel
# Processing Record 12 of Set 11 | chunar
# Processing Record 13 of Set 11 | morant bay
# Processing Record 14 of Set 11 | douentza
# Processing Record 15 of Set 11 | aleksandrovskiy zavod
# Processing Record 16 of Set 11 | prince rupert
# Processing Record 17 of Set 11 | san rafael
# Processing Record 18 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 19 of Set 11 | tongzi
# Processing Record 20 of Set 11 | ludvika
# Processing Record 21 of Set 11 | kalevala
# Processing Record 22 of Set 11 | pitimbu
# Processing Record 23 of Set 11 | vao
# Processing Record 24 of Set 11 | gaoua
# Processing Record 25 of Set 11 | makakilo city
# Processing Record 26 of Set 11 | mocambique
# City not found. Skipping...
# Processing Record 27 of Set 11 | camopi
# Processing Record 28 of Set 11 | greenville
# Processing Record 29 of Set 11 | huarmey
# Processing Record 30 of Set 11 | tabas
# Processing Record 31 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 32 of Set 11 | sao joao da barra
# Processing Record 33 of Set 11 | yining
# Processing Record 34 of Set 11 | esperance
# Processing Record 35 of Set 11 | mahalapye
# Processing Record 36 of Set 11 | san jose
# Processing Record 37 of Set 11 | leshukonskoye
# Processing Record 38 of Set 11 | verkh-usugli
# Processing Record 39 of Set 11 | gumdag
# Processing Record 40 of Set 11 | katsuura
# Processing Record 41 of Set 11 | isiro
# Processing Record 42 of Set 11 | hong gai
# Processing Record 43 of Set 11 | nizhniy baskunchak
# Processing Record 44 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 45 of Set 11 | brigham city
# Processing Record 46 of Set 11 | port macquarie
# Processing Record 47 of Set 11 | adrar
# Processing Record 48 of Set 11 | kalaleh
# Processing Record 49 of Set 11 | linda
# Processing Record 50 of Set 11 | port-gentil
# Processing Record 1 of Set 12 | havoysund
# Processing Record 2 of Set 12 | tocantinopolis
# City not found. Skipping...
# Processing Record 3 of Set 12 | dicabisagan
# Processing Record 4 of Set 12 | gasa
# Processing Record 5 of Set 12 | filingue
# Processing Record 6 of Set 12 | pilao arcado
# City not found. Skipping...
# Processing Record 7 of Set 12 | lasa
# Processing Record 8 of Set 12 | san quintin
# Processing Record 9 of Set 12 | banjar
# Processing Record 10 of Set 12 | cap malheureux
# Processing Record 11 of Set 12 | sao jose da coroa grande
# Processing Record 12 of Set 12 | cairns
# Processing Record 13 of Set 12 | poddorye
# Processing Record 14 of Set 12 | nikolayevka
# Processing Record 15 of Set 12 | nayoro
# Processing Record 16 of Set 12 | aden
# Processing Record 17 of Set 12 | monticello
# Processing Record 18 of Set 12 | krasnoyarskiy
# Processing Record 19 of Set 12 | houma
# Processing Record 20 of Set 12 | labuhan
# Processing Record 21 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 12 | sault sainte marie
# Processing Record 23 of Set 12 | port blair
# Processing Record 24 of Set 12 | tambopata
# Processing Record 25 of Set 12 | vung tau
# Processing Record 26 of Set 12 | muncar
# Processing Record 27 of Set 12 | buchanan
# Processing Record 28 of Set 12 | mount isa
# Processing Record 29 of Set 12 | umarkot
# Processing Record 30 of Set 12 | high level
# Processing Record 31 of Set 12 | naron
# Processing Record 32 of Set 12 | namibe
# Processing Record 33 of Set 12 | zabol
# Processing Record 34 of Set 12 | nioro
# Processing Record 35 of Set 12 | andilamena
# Processing Record 36 of Set 12 | san luis
# Processing Record 37 of Set 12 | puerto madryn
# Processing Record 38 of Set 12 | carauari
# Processing Record 39 of Set 12 | hukeri
# Processing Record 40 of Set 12 | lamu
# Processing Record 41 of Set 12 | beisfjord
# Processing Record 42 of Set 12 | kota kinabalu
# Processing Record 43 of Set 12 | manta
# Processing Record 44 of Set 12 | bhakkar
# Processing Record 45 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 12 | mumford
# Processing Record 47 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 48 of Set 12 | batagay
# Processing Record 49 of Set 12 | bossembele
# City not found. Skipping...
# Processing Record 50 of Set 12 | lumeje
# Processing Record 1 of Set 13 | dashitou
# Processing Record 2 of Set 13 | maghama
# City not found. Skipping...
# Processing Record 3 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 4 of Set 13 | flagstaff
# Processing Record 5 of Set 13 | belaya gora
# Processing Record 6 of Set 13 | willmar
# Processing Record 7 of Set 13 | qiyang
# Processing Record 8 of Set 13 | klyuchi
# Processing Record 9 of Set 13 | reporoa
# Processing Record 10 of Set 13 | kaeo
# Processing Record 11 of Set 13 | fairbanks
# Processing Record 12 of Set 13 | burnie
# Processing Record 13 of Set 13 | santa cruz de la palma
# Processing Record 14 of Set 13 | karmaskaly
# Processing Record 15 of Set 13 | revda
# Processing Record 16 of Set 13 | christchurch
# Processing Record 17 of Set 13 | moyo
# Processing Record 18 of Set 13 | guantanamo
# Processing Record 19 of Set 13 | koratla
# Processing Record 20 of Set 13 | kampene
# Processing Record 21 of Set 13 | benemerito de las americas
# Processing Record 22 of Set 13 | sosnogorsk
# Processing Record 23 of Set 13 | mandalgovi
# Processing Record 24 of Set 13 | moussoro
# Processing Record 25 of Set 13 | parlakimidi
# Processing Record 26 of Set 13 | kiunga
# Processing Record 27 of Set 13 | great yarmouth
# Processing Record 28 of Set 13 | salsomaggiore terme
# Processing Record 29 of Set 13 | nizhniy odes
# Processing Record 30 of Set 13 | saint andrews
# Processing Record 31 of Set 13 | terrak
# Processing Record 32 of Set 13 | rundu
# Processing Record 33 of Set 13 | namuac
# Processing Record 34 of Set 13 | calbuco
# Processing Record 35 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 36 of Set 13 | waitati
# Processing Record 37 of Set 13 | ahipara
# Processing Record 38 of Set 13 | shache
# Processing Record 39 of Set 13 | puerto suarez
# Processing Record 40 of Set 13 | pocos de caldas
# Processing Record 41 of Set 13 | wewak
# Processing Record 42 of Set 13 | ati
# Processing Record 43 of Set 13 | naberera
# Processing Record 44 of Set 13 | lusambo
# Processing Record 45 of Set 13 | russell
# Processing Record 46 of Set 13 | ngunguru
# Processing Record 47 of Set 13 | newport
# Processing Record 48 of Set 13 | mackay
# Processing Record 49 of Set 13 | mvuma
# Processing Record 50 of Set 13 | slave lake
# Processing Record 1 of Set 14 | aksarka
# Processing Record 2 of Set 14 | mbandaka
# Processing Record 3 of Set 14 | champasak
# Processing Record 4 of Set 14 | bima
# Processing Record 5 of Set 14 | luba
# Processing Record 6 of Set 14 | tres arroyos
# Processing Record 7 of Set 14 | atherton
# Processing Record 8 of Set 14 | rumphi
# Processing Record 9 of Set 14 | mirandopolis
# Processing Record 10 of Set 14 | salym
# Processing Record 11 of Set 14 | payo
# Processing Record 12 of Set 14 | zhigansk
# Processing Record 13 of Set 14 | hualmay
# Processing Record 14 of Set 14 | derzhavinsk
# Processing Record 15 of Set 14 | montepulciano
# Processing Record 16 of Set 14 | zaykovo
# Processing Record 17 of Set 14 | mahibadhoo
# Processing Record 18 of Set 14 | lazaro cardenas
# Processing Record 19 of Set 14 | muisne
# Processing Record 20 of Set 14 | bang saphan
# Processing Record 21 of Set 14 | tandil
# Processing Record 22 of Set 14 | inhambane
# Processing Record 23 of Set 14 | ginir
# Processing Record 24 of Set 14 | eyrarbakki
# Processing Record 25 of Set 14 | praia da vitoria
# Processing Record 26 of Set 14 | tromso
# Processing Record 27 of Set 14 | hobyo
# Processing Record 28 of Set 14 | mooresville
# Processing Record 29 of Set 14 | alofi
# Processing Record 30 of Set 14 | sibolga
# Processing Record 31 of Set 14 | chichicapam
# City not found. Skipping...
# Processing Record 32 of Set 14 | belyy yar
# Processing Record 33 of Set 14 | ayan
# Processing Record 34 of Set 14 | severo-yeniseyskiy
# Processing Record 35 of Set 14 | lokosovo
# Processing Record 36 of Set 14 | tazagyukh
# City not found. Skipping...
# Processing Record 37 of Set 14 | taonan
# Processing Record 38 of Set 14 | san martin
# Processing Record 39 of Set 14 | kremze
# Processing Record 40 of Set 14 | komyshnya
# Processing Record 41 of Set 14 | luena
# Processing Record 42 of Set 14 | nadym
# Processing Record 43 of Set 14 | bozoum
# Processing Record 44 of Set 14 | manokwari
# Processing Record 45 of Set 14 | bonawon
# Processing Record 46 of Set 14 | surt
# Processing Record 47 of Set 14 | porto walter
# Processing Record 48 of Set 14 | mecca
# Processing Record 49 of Set 14 | peru
# Processing Record 50 of Set 14 | ekhabi
# Processing Record 1 of Set 15 | salaga
# Processing Record 2 of Set 15 | coahuayana
# Processing Record 3 of Set 15 | oum hadjer
# Processing Record 4 of Set 15 | hvide sande
# Processing Record 5 of Set 15 | honningsvag
# Processing Record 6 of Set 15 | rorvik
# Processing Record 7 of Set 15 | kampot
# Processing Record 8 of Set 15 | gornopravdinsk
# Processing Record 9 of Set 15 | juli
# Processing Record 10 of Set 15 | temple
# Processing Record 11 of Set 15 | cristalina
# Processing Record 12 of Set 15 | modra
# Processing Record 13 of Set 15 | sangar
# Processing Record 14 of Set 15 | jiuquan
# Processing Record 15 of Set 15 | sorland
# Processing Record 16 of Set 15 | longonjo
# Processing Record 17 of Set 15 | chumikan
# Processing Record 18 of Set 15 | trairi
# Processing Record 19 of Set 15 | kinango
# Processing Record 20 of Set 15 | gombong
# Processing Record 21 of Set 15 | ha tinh
# Processing Record 22 of Set 15 | ondo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Create DataFrame from list
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Description']
city_data_df = pd.DataFrame(city_data)
city_data_df=city_data_df[new_column_order]
city_data_df.head(1)
# Out:
#               City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0  Arraial Do Cabo      BR -22.9661 -42.0278     87.76        58           0
#
#    Wind Speed Description
# 0       16.11   clear sky

# %%
#Output variable/ file name
output_file="./WeatherPy_Database.csv"

#Output to CSV
city_data_df.to_csv(output_file, index_label="City_ID")
